# %% [markdown]
# ADS ASSIGNMENT 1

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt
import seaborn as sns

# %%
def countplot(dataframe, x_val, plot_title='', figsize=(15,8)):
    plt.figure(figsize=figsize)
    plt.title(plot_title)
    sns.countplot(data=df, x=x_val)
    plt.show()

# %% [markdown]
# Reading and viewing the dataset

# %%
def barplot(dataframe, x_val, y_val):
    sns.barplot(data=dataframe, x=x_val, y=y_val)
    plt.title(x_val.title() + ' vs ' + y_val.title())
    plt.show()

# %% [markdown]
# The dataset is loaded and found that there are 23 columns present in the given dataset

# %%
df = pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %% [markdown]
# It is founded that there are 14620 rows and 23 columns in the dataset
# Which means that there are 14620 data with 23 features

# %%
pd.DataFrame(list(df.columns), columns=['Column Name'])
# Out:
#                               Column Name
# 0                                      id
# 1                                    Date
# 2                      number of bedrooms
# 3                     number of bathrooms
# 4                             living area
# 5                                lot area
# 6                        number of floors
# 7                      waterfront present
# 8                         number of views
# 9                  condition of the house
# 10                     grade of the house
# 11  Area of the house(excluding basement)
# 12                   Area of the basement
# 13                             Built Year
# 14                        Renovation Year
# 15                            Postal Code
# 16                              Lattitude
# 17                              Longitude
# 18                      living_area_renov
# 19                         lot_area_renov
# 20               Number of schools nearby
# ...

# %% [markdown]
# Univariate Analysis

# %%
df.shape
# Out:
# (14620, 23)

# %% [markdown]
# From the above plot it is inferred that,
# There are more number of houses with 3 bedrooms and the houses with more than 7 bedrooms are very less in count.
# The second largest count of houses are with 4 number of bedrooms.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %% [markdown]
# From the above plot it is inferred that,
# There are many houses with 2.5 bathrooms, and the second is the houses with 1 bathrooms.
# Houses with 0.5, 1.25, and above 4.25 are very less in count.

# %%
countplot(dataframe=df, x_val='number of bedrooms', plot_title='Count of Number of Bedrooms')

# %% [markdown]
# From the above plot it is inferred that,
# There are more houses with 1 floor.
# And the second largest number of homes are with 2 floors.
# We can see the homes with 2.5 and 3.5 floors are of least number of counts.

# %%
countplot(dataframe=df, x_val='waterfront present', figsize=(8,6), plot_title='Water present (1) or not (0)')

# %% [markdown]
# It is founded that there are more than 14000 houses without water in front.
# There are very less amount of home contains water in the front.

# %%
countplot(dataframe=df, x_val='number of bathrooms', plot_title='Count of Number of Bathrooms')

# %% [markdown]
# From the above plot it is inferred that,
# There are huge number of houses with 0 views.
# The second large number of houses are with 2 views.
# The houses with 1 and 4 views are very less in number.

# %%
countplot(dataframe=df, x_val='number of floors', figsize=(8,5), plot_title='Count of Number of Floors')

# %% [markdown]
# From the above plot it is inferred that,
# There are many houses with normal condition that is the medium condition.
# The houses which have good conditions are less in count.
# There are very less number of houses which are in very worst conditions.

# %%
countplot(dataframe=df, x_val='grade of the house', figsize=(8,5), plot_title='Grade of the House')

# %% [markdown]
# From the above plot it is inferred that,
# There are many houses with grade 7.
# Grade 8 houses are ranking two on count.
# The houses with grade 4 and 13 are very lesser in count.

# %%
countplot(dataframe=df, x_val='Number of schools nearby', figsize=(8,5), plot_title='Number of Schools Nearby')

# %% [markdown]
# From the above plot it is inferred that,
# There are houses which contains 3 schools in near are of higher number.
# The houses with 1 school nearby is slightly less in number compared to that of the other houses.

# %%
sns.displot(df['Price'])
plt.title('Price Distribution')
plt.show()

# %% [markdown]
# From the above plot it is inferred that,
# The plot is right skewed.
# This means that majority of the houses are less priced.

# %%
sns.histplot(data=df, x='Distance from the airport')
plt.show()

# %% [markdown]
# From the above plot it is inferred that,
# There are many houses whose distance from the airport is near to the multiples of 5 ranging from 50 to 80 kms.
# The rest of the distanced houses from the airport are less in number when compared to the other houses.

# %%
sns.barplot(data=df, x='Number of schools nearby', y='Distance from the airport')
plt.title('Number of schools vs Distance from airport')
plt.show()

# %% [markdown]
# From the above plot it is inferred that,
# The number of schools and the Distance from airport from the houses are almost same.
# The distance from the airport to the house with schools are of more than 60 kms.

# %%
barplot(dataframe=df, x_val='number of bedrooms', y_val='number of bathrooms')

# %% [markdown]
# From the above plot it is inferred that,
# We can see the wide spread of number of bathrooms for the 9 count of bedrooms.
# There is no errors bars for the 11 and 33 number of bedrooms.
# The 9 count of bedroom contain a maximum of the number of bathroom.
# The 33 bedroom house only contains 2 bathrooms in it.

# %%
barplot(dataframe=df, x_val='number of floors', y_val='number of bathrooms')

# %% [markdown]
# From the above plot it is inferred that,
# The number of floors is likely proportional to the number of bathrooms.
# This shows that the number of floors increases, increases the count of bathrooms.

# %%
barplot(dataframe=df, x_val='number of floors', y_val='number of bedrooms')

# %% [markdown]
# From the above plot it is inferred that,
# The number of bedrooms and the numbers of floors are somewhat similar.
# There isn't much variation between those two.

# %%
barplot(dataframe=df, x_val='condition of the house', y_val='grade of the house')

# %% [markdown]
# From the above plot it is inferred that,
# The higher the condition of the house is the house with more amount of grade.
# But the low condition house got around 6+ grade.

# %%
barplot(dataframe=df, x_val='number of views', y_val='grade of the house')

# %% [markdown]
# From the above plot it is inferred that,
# the higher the views gives higher the grade of the house.
# The house with 4 views constitute the higher grade among the rest of the houses.

# %%
barplot(dataframe=df, x_val='condition of the house', y_val='number of views')

# %% [markdown]
# From the above plot it is inferred that,
# The condition of the houses increases with increase in the number of views.
# This shows that the number of views and the condition of the houses are proportional.

# %%
fig = plt.figure(figsize = [30, 18]) # defining entire figure size

for i in range(1, len(list(df.columns))):
    plt.subplot(8, 3, i) # makes subplot
    
    fig.tight_layout(pad=2) # gives space between the subplots
    df_new = df.iloc[:,i] # making new dataframe using slicing technique to remote the unwanted columns
    
    plt.suptitle('Comparision of all Features') # main title
    plt.title(list(df.columns)[i]) # title for each subplots
    
    sns.boxenplot(df_new) # making boxen plot

plt.show()

# %% [markdown]
# The inferrence of the above plot is discussed below,
#
# Date:
# There is no much outliers founded.
# Most of the data are fount between 42550 and 42650.
#
# Number of bedrooms:
# We can see a some amount of outliers in this column.
# This should be cleared out otherwise it may lead to cause some problems.
# Most of the data are fount in the range of 3 and 4.
#
# Number of bathrooms:
# We can see a huge amount of outliers which are need to be removed to avoid some problems.
# Most of the count of bathrooms are lies in the range of 2 and 3.
#
# Living Area:
# We can see some of the outliers in this feature.
# This should be handled to avoid some issues.
# Most of the area ranges around 2000.
#
# Lot Area:
# We can see a large amount of outliers which should be managed.
# Most of the data lies around 02e6.
#
# Number of Floors:
# There are few outliers which can be dropped.
# This wont affect the huge data.
# The number of floors rnges commonly around 2 to 3 floors.
#
# Water Front Present:
# There is no water front present in most of the house.
# There are very few amount of houses which contains the water front.
#
# Number of Views:
# We can see that there are more number of houses with 0 views.
# Some of the houses contains around 2 views.
#
# Condition of the House:
# We can see that the condition of most of the house are on average.
# some of the houses are of very good condition.
# Very few amount of the houses contains very worst condition.
#
# Grade of the House:
# There are no outliers.
# It is a good data containing the grade of the house.
# Most of the house contains an average grade.
#
# Area of house:
# There are more number of outliers which are to be managed carefully.
# There are more number of houses with an average area between 1000 and 3000.
#
# Area of Basement:
# We can see a wide range of outliers present in this features.
# These outliers should be handles very caarefully as this represents the area.
# The values ranges very low which is less then around 750.
#
# Build Year:
# This is a clear data without any outliers.
# The data are distributed very properly.
# Renovation year:
# There are some of the outliers which should be handled.
# There are around 25 percentile data which spreads in a huge range.
#
# Postal Code:
# This shouldn't be altered.
# This has good distribution of data.
#
# Living Area Renov:
# This contains some of the outliers which should be handled carefully as it is an area.
# Majority of area lies between 1000 and 3000.
#
# Lot Area Renov:
# This also contains a huge amount of outliers which should be handled.
# There are very less amount of area are revovated in case of the lot area.
#
# Number of Schools Nearby:
# This is a good distribution of data.
# The data ranges between 1 and3 number of schools.
#
# Distance from airport:
# This doesn't contains the outliers.
# This feature contain very good distribution of data.
# The distances are ranges from 65 kms to 75 kms on an higher average.

# %%
df.iloc[:,2:].describe()
# Out:
#        number of bedrooms  number of bathrooms   living area      lot area  \
# count        14620.000000         14620.000000  14620.000000  1.462000e+04
# mean             3.379343             2.129583   2098.262996  1.509328e+04
# std              0.938719             0.769934    928.275721  3.791962e+04
# min              1.000000             0.500000    370.000000  5.200000e+02
# 25%              3.000000             1.750000   1440.000000  5.010750e+03
# 50%              3.000000             2.250000   1930.000000  7.620000e+03
# 75%              4.000000             2.500000   2570.000000  1.080000e+04
# max             33.000000             8.000000  13540.000000  1.074218e+06
#
#        number of floors  waterfront present  number of views  \
# count      14620.000000        14620.000000     14620.000000
# mean           1.502360            0.007661         0.233105
# std            0.540239            0.087193         0.766259
# ...

# %% [markdown]
# Checking for NaN values

# %%
df.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# It is founded that there are no null values in the given dataset.
# So there is no need of handling the NaN values.
